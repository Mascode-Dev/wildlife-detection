# %%
from ultralytics import YOLO
# Out:
# WARNING torchvision==0.24 is incompatible with torch==2.8.
# Run 'pip install torchvision==0.23' to fix torchvision or 'pip install -U torch torchvision' to update both.
# For a full compatibility table see https://github.com/pytorch/vision#installation

# %%
# Load the trained model
model = YOLO('runs/detect/wildlife_detection_v1/weights/best.pt')

# Detect on a new folder of unannotated images
results = model.predict(
    source='path/to/new_camera_trap_images/', 
    save=True, 
    conf=0.25, # Minimum confidence threshold (adjust if the model is too sensitive)
    save_txt=True # Save results in YOLO format if needed
)
